# %%
print("Hello, everyone! I am learning Python. 😄")
# Out:
# Hello, everyone! I am learning Python. 😄

# %%
Name="Muhammad Anees"
Age=24
favoriteAnimal="Goat"
print("My name is:",Name)
print("My age is:,",Age)
print("My favorite animal is :", favoriteAnimal)
# Out:
# My name is: Muhammad Anees
# My age is:, 24
# My favorite animal is : Goat

# %%
# print all variable in a line using one print fuction

print("My name is",(Name) + ",I am",Age, "year old, and I love",favoriteAnimal+"!")
# Out:
# My name is Muhammad Anees,I am 24 year old, and I love Goat!

# %%
movie = "Toy Story"
birth_year = 2010
price = 1.5

print("Favorite Movie:", movie)
print("Birth Year:", birth_year)
print("Price of Snack:", price)
# Out:
# Favorite Movie: Toy Story
# Birth Year: 2010
# Price of Snack: 1.5

# %%
hobby="Reading books"
print("My favorite hobby is",hobby)
# Out:
# My favorite hobby is Reading books

# %%
#only + function 
a=4
b=6
c=a+b
print("a=",a)
print("b=",b)
print("c=",c,"(a and b combined!)")
# Out:
# a= 4
# b= 6
# c= 10 (a and b combined!)
